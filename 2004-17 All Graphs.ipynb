# %% [markdown]
# |      | Total | Active Region | Active Prominence | Prominence Eruption | NDA | BK  | Blanks |
# |------|-------|---------------|-------------------|---------------------|-----|-----|--------|
# | 2004 | 402   | 148           | 42                | 34                  | 70  | 103 | 5      |
# | 2017 | 342   | 211           | 21                | 13                  | 20  | 14  | 50     |

# %%
import pandas as pb

x=pb.read_csv('ALL GRAPH DATA.csv')
#x.head()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()

fig, (ax,ax1) = plt.subplots(1, 2, sharex=True, sharey=True, figsize=(15,5))
fig.suptitle('Latitude VS Position Angle', size=25)
ax.set_title('2004', size=17)
ax1.set_title('2017', size=17)


sns.scatterplot(ax=ax,x='PA',y='LAT',data=x,hue='AR/AP/PE',s=40);
ax.set_xlabel('Position Angle',size=13)
ax.set_ylabel('Latitude',size=13)

sns.scatterplot(ax=ax1,x='pa',y='lat',data=x,hue='AR/AP/PE',s=40);
ax1.set_xlabel('Position Angle',size=13)
# Out:
# Text(0.5, 0, 'Position Angle')

# %%
import seaborn as sns
import numpy as np
from matplotlib import pyplot as plt
sns.set()

fig, ((ax,ax1),(ax2,ax3),(ax4,ax5)) = plt.subplots(3, 2, sharex=False, sharey='row', figsize=(15,20))
fig.suptitle('POSITION ANGLE DISTRIBUTION', fontsize=20)

sns.histplot(ax=ax, x='AR PA',data=x,bins=8,color = "skyblue")
ax.set_xlabel('Position Angle',size=13)
ax.set_title('2004',size=16)
ax.text(30, 65, 'ACTIVE REGION' ,bbox={'facecolor': 'white', 'alpha': 0.5, 'pad': 10})

sns.histplot(ax=ax1, x='ar pa',data=x,bins=8)
ax1.set_xlabel('Position Angle',size=13)
ax1.set_title('2017',size=16)

sns.histplot(ax=ax2, x='PE PA',data=x,bins=8)
ax2.set_xlabel('Position Angle',size=13)
ax2.text(30, 6.5, 'PROMINENCE ERRUPTION',bbox={'facecolor': 'white', 'alpha': 0.5, 'pad': 10})

sns.histplot(ax=ax3, x='pe pa',data=x,bins=8)
ax3.set_xlabel('Position Angle',size=13)

sns.histplot(ax=ax4, x='AP PA',data=x,bins=8)
ax4.set_xlabel('Position Angle',size=13)
ax4.set_xlim([0, 360])
ax4.text(30, 11, 'ACTIVE PROMINENCES',bbox={'facecolor': 'white', 'alpha': 0.5, 'pad': 10})

sns.histplot(ax=ax5, x='ap pa',data=x,bins=8)
ax5.set_xlabel('Position Angle',size=13)
ax5.set_xlim([0, 360])
# Out:
# (0.0, 360.0)

# %%
import seaborn as sns
import numpy as np
from matplotlib import pyplot as plt
sns.set()

fig, ((ax,ax1),(ax2,ax3),(ax4,ax5)) = plt.subplots(3, 2, sharex=False, sharey='row', figsize=(15,20))
fig.suptitle('LATITUDE DISTRIBUTION', fontsize=20)

sns.histplot(ax=ax, x='AR LAT',data=x,bins=8)
ax.set_xlabel('Latitude',size=13)
ax.set_title('2004',size=16)
ax.text(-45, 55, 'ACTIVE REGION' ,bbox={'facecolor': 'white', 'alpha': 0.5, 'pad': 10})
ax.set_xlim([-60, 60])

sns.histplot(ax=ax1, x='ar lat',data=x,bins=8)
ax1.set_xlabel('Latitude',size=13)
ax1.set_title('2017',size=16)
ax1.set_xlim([-60, 60])

sns.histplot(ax=ax2, x='PE LAT',data=x,bins=8)
ax2.set_xlabel('Latitude',size=13)
ax2.set_xlim([-60, 60])
ax2.text(5, 5.5, 'PROMINENCE ERRUPTION',bbox={'facecolor': 'white', 'alpha': 0.5, 'pad': 10})

sns.histplot(ax=ax3, x='pe lat',data=x,bins=8)
ax3.set_xlabel('Latitude',size=13)
ax3.set_xlim([-60, 60])

sns.histplot(ax=ax4, x='AP LAT',data=x,bins=8)
ax4.set_xlabel('Latitude',size=13)
ax4.set_xlim([-60, 60])
ax4.text(-45, 16, 'ACTIVE PROMINENCES',bbox={'facecolor': 'white', 'alpha': 0.5, 'pad': 10})

sns.histplot(ax=ax5, x='ap lat',data=x,bins=8)
ax5.set_xlabel('Latitude',size=13)
ax5.set_xlim([-60, 60])
# Out:
# (-60.0, 60.0)

# %%
import seaborn as sns
import numpy as np
from matplotlib import pyplot as plt
sns.set()

fig, ((ax,ax1),(ax2,ax3),(ax4,ax5)) = plt.subplots(3, 2, sharex=False, sharey='row', figsize=(15,20))
fig.suptitle('LONGITUDE DISTRIBUTION', fontsize=20)

sns.histplot(ax=ax, x='AR LONG',data=x,bins=8)
ax.set_xlabel('Longitude',size=13)
ax.set_title('2004',size=16)
ax.text(-180, 50, 'ACTIVE REGION' ,bbox={'facecolor': 'white', 'alpha': 0.5, 'pad': 10})
ax.set_xlim([-200, 200])

sns.histplot(ax=ax1, x='ar long',data=x,bins=8)
ax1.set_xlabel('Longitude',size=13)
ax1.set_title('2017',size=16)
ax1.set_xlim([-200, 200])

sns.histplot(ax=ax2, x='PE LONG',data=x,bins=8)
ax2.set_xlabel('Longitude',size=13)
ax2.set_xlim([-200, 200])
ax2.text(-180, 6.5, 'PROMINENCE ERRUPTION',bbox={'facecolor': 'white', 'alpha': 0.5, 'pad': 10})

sns.histplot(ax=ax3, x='pe long',data=x,bins=8)
ax3.set_xlabel('Longitude',size=13)
ax3.set_xlim([-200, 200])

sns.histplot(ax=ax4, x='AP LONG',data=x,bins=8)
ax4.set_xlabel('Longitude',size=13)
ax4.set_xlim([-200, 200])
ax4.text(-180, 6.5, 'ACTIVE PROMINENCES',bbox={'facecolor': 'white', 'alpha': 0.5, 'pad': 10})

sns.histplot(ax=ax5, x='ap long',data=x,bins=8)
ax5.set_xlabel('Longitude',size=13)
ax5.set_xlim([-200, 200])
# Out:
# (-200.0, 200.0)

# %%
import seaborn as sns
import numpy as np
from matplotlib import pyplot as plt
sns.set()

fig, ((ax,ax1),(ax2,ax3),(ax4,ax5)) = plt.subplots(3, 2, sharex=False, sharey='row', figsize=(15,20))
fig.suptitle('SPEED DISTRIBUTION', fontsize=20)

sns.histplot(ax=ax, x='AR SPEED',data=x,bins=8)
ax.set_xlabel('Speed',size=13)
ax.set_title('2004',size=16)
ax.text(1000,80, 'ACTIVE REGION' ,bbox={'facecolor': 'white', 'alpha': 0.5, 'pad': 10})
ax.set_xlim([0,1800])

sns.histplot(ax=ax1, x='ar speed',data=x,bins=8)
ax1.set_xlabel('Speed',size=13)
ax1.set_title('2017',size=16)
ax1.set_xlim([0,1800])

sns.histplot(ax=ax2, x='PE SPEED',data=x,bins=8)
ax2.set_xlabel('Speed',size=13)
ax2.set_xlim([0,1800])
ax2.text(1000, 5.5, 'PROMINENCE ERRUPTION',bbox={'facecolor': 'white', 'alpha': 0.5, 'pad': 10})

sns.histplot(ax=ax3, x='pe speed',data=x,bins=8)
ax3.set_xlabel('Speed',size=13)
ax3.set_xlim([0,1800])

sns.histplot(ax=ax4, x='AP SPEED',data=x,bins=8)
ax4.set_xlabel('Speed',size=13)
ax4.set_xlim([0,1800])
ax4.text(1000, 15, 'ACTIVE PROMINENCES',bbox={'facecolor': 'white', 'alpha': 0.5, 'pad': 10})

sns.histplot(ax=ax5, x='ap speed',data=x,bins=8)
ax5.set_xlabel('Speed',size=13)
ax5.set_xlim([0,1800])
# Out:
# (0.0, 1800.0)

# %%
import seaborn as sns
import numpy as np
from matplotlib import pyplot as plt
sns.set()

fig, ((ax,ax1),(ax2,ax3),(ax4,ax5)) = plt.subplots(3, 2, sharex=False, sharey='row', figsize=(15,20))
fig.suptitle('WIDTH DISTRIBUTION', fontsize=20)

sns.histplot(ax=ax, x='AR WIDTH',data=x,bins=8)
ax.set_xlabel('WIDTH',size=13)
ax.set_title('2004',size=16)
ax.text(120,110, 'ACTIVE REGION' ,bbox={'facecolor': 'white', 'alpha': 0.5, 'pad': 10})
ax.set_xlim([0,250])

sns.histplot(ax=ax1, x='ar width',data=x,bins=8)
ax1.set_xlabel('WIDTH',size=13)
ax1.set_title('2017',size=16)
ax1.set_xlim([0,250])

sns.histplot(ax=ax2, x='PE WIDTH',data=x,bins=8)
ax2.set_xlabel('WIDTH',size=13)
ax2.set_xlim([0,250])
ax2.text(120, 5.5, 'PROMINENCE ERRUPTION',bbox={'facecolor': 'white', 'alpha': 0.5, 'pad': 10})

sns.histplot(ax=ax3, x='pe width',data=x,bins=8)
ax3.set_xlabel('WIDTH',size=13)
ax3.set_xlim([0,250])

sns.histplot(ax=ax4, x='AP WIDTH',data=x,bins=8)
ax4.set_xlabel('WIDTH',size=13)
ax4.set_xlim([0,250])
ax4.text(120, 14, 'ACTIVE PROMINENCES',bbox={'facecolor': 'white', 'alpha': 0.5, 'pad': 10})

sns.histplot(ax=ax5, x='ap width',data=x,bins=8)
ax5.set_xlabel('WIDTH',size=13)
ax5.set_xlim([0,250])
# Out:
# (0.0, 250.0)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()

fig, (ax,ax1) = plt.subplots(1, 2, sharex=True, sharey=True, figsize=(15,5))
fig.suptitle('Speed VS Width', size=25)
ax.set_title('2004', size=17)
ax1.set_title('2017', size=17)


sns.scatterplot(ax=ax,x='WIDTH',y='SPEED',data=x,hue='AR/AP/PE',s=40);
ax.set_xlabel('Width',size=13)
sns.scatterplot(ax=ax1,x='width',y='speed',data=x,hue='AR/AP/PE',s=40);
ax1.set_xlabel('Width',size=13)
# Out:
# Text(0.5, 0, 'Width')
